# %% [markdown]
# ### Problem Set
# - **App Store Data-Set :**
#     - List of all unique Prime_Genres(categories) in the data sets.
#     - Category with highest number of apps
#     - Category with lowest number of apps
#     - Category with highest user rating
#     - App with highest downloads
#     - Category with highest average rating count  ------------------
#     - Average user rating for free apps
#     - Average user rating for paid apps
#     - Category with highest average user rating for paid apps  ------------
#     - Most frequent Price Point > 0
#     - Compare average user rating for paid vs free gaming apps

# %%
import pandas as pd
appstore = pd.read_csv("AppleStore.csv")
appstore
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# 7167       10995  1182265441
# 7168       10998  1182331762
# 7169       11002  1182568288
# 7170       11010  1183234072
# 7171       11013  1183260922
# 7172       11016  1183548754
# 7173       11019  1183709176
# 7174       11022  1183856228
# 7175       11024  1183986102
# 7176       11027  1184711626
# 7177       11031  1184800011
# 7178       11033  1185209084
# 7179       11035  1185328193
# 7180       11036  1185365336
# 7181       11038  1185428381
# 7182       11040  1185538497
# 7183       11041  1185580782
# 7184       11042  1185731859
# 7185       11043  1185777521
# 7186       11050  1186108496
# 7187       11051  1186126548
# 7188       11060  1186384912
# 7189       11074  1187128255
# 7190       11077  1187279979
# 7191       11079  1187282363
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# 5                                      Shanghai Mahjong    10485713      USD
# 6                PayPal - Send and request money safely   227795968      USD
# 7                               Pandora - Music & Radio   130242560      USD
# 8                           PCalc - The Best Calculator    49250304      USD
# 9                                           Ms. PAC-MAN    70023168      USD
# 10                            Solitaire by MobilityWare    49618944      USD
# 11                                     SCRABBLE Premium   227547136      USD
# 12                 Google – Search made just for mobile   179979264      USD
# 13                     Bank of America - Mobile Banking   160925696      USD
# 14                                             FreeCell    55153664      USD
# 15               TripAdvisor Hotels Flights Restaurants   207907840      USD
# 16                                             Facebook   389879808      USD
# 17       Yelp - Nearby Restaurants, Shopping & Services   167407616      USD
# 18    Shazam - Discover music, artists, videos & lyrics   147093504      USD
# 19                        Crash Bandicoot Nitro Kart 3D    10735026      USD
# 20                                               iQuran    70707916      USD
# 21                                          :) Sudoku +     6169600      USD
# 22      Yahoo Sports - Teams, Scores, News & Highlights   130583552      USD
# 23                            Mileage Log | Fahrtenbuch    71203840      USD
# 24                          Cleartune - Chromatic Tuner    11423008      USD
# 25            Lifesum – Inspiring healthy lifestyle app   188017664      USD
# 26                                             Hangman.     4765696      USD
# 27        iTranslate - Language Translator & Dictionary   287933440      USD
# 28                                             TouchOSC     4263936      USD
# 29                                           RadarScope   172772352      USD
# ...                                                 ...         ...      ...
# 7167                      脱出ゲーム　わたしをみつけて　-おじいさんとわたしの物語-   177498112      USD
# 7168                      Escape from the frigid Igloo.    89188352      USD
# 7169        Talking Santa - Video santa claus calls you    32685056      USD
# 7170                                          CTFxCmoji    26077184      USD
# 7171                    Room Escape Game - Santa's Room   143346688      USD
# 7172                               Rescue the Enchanter   242505728      USD
# 7173                                 My Diary - 你的名字非官方    18164736      USD
# 7174  VR Thrills: Roller Coaster 360 (Google Cardboard)   169535488      USD
# 7175   Santa Kids Hair Salon - Christmas Makeover Games    64244736      USD
# 7176                                 Human Juggling Cup   184324096      USD
# 7177                           Again - room escape game    33946624      USD
# 7178                                  Saloons Unleashed   327731200      USD
# 7179             Fam — Group video calling for iMessage   113382400      USD
# 7180                   Laurie Hernandez the Human Emoji    94008320      USD
# 7181                                               剑倚手游   178160640      USD
# 7182                                  camera for filter     9362432      USD
# 7183                                    Survivalcraft 2    57349120      USD
# 7184                                    剑客情缘-高爆率高掉落天天疯玩   171944960      USD
# 7185                                     问仙奇遇-新玩法新套装嗨到爆   208026624      USD
# 7186                 脱出ゲーム - 書道教室 -  "漢字"の謎に満ちた部屋からの 脱出    85580800      USD
# 7187                          Escape Game: illumination    52342784      USD
# 7188       Demolition Derby Virtual Reality (VR) Racing   168774656      USD
# 7189                         飞刀传奇-动作武侠热血江湖即时PK传奇（登录爆金装）   537462784      USD
# 7190                       Add-Ons Studio for Minecraft    22999040      USD
# 7191                         Plead the Fifth - The Game    27853824      USD
# 7192                                              Kubik   126644224      USD
# 7193                                  VR Roller-Coaster   120760320      USD
# 7194              Bret Michaels Emojis + Lyric Keyboard   111322112      USD
# 7195          VR Roller Coaster World - Virtual Reality    97235968      USD
# 7196                       Escape the Sweet Shop Series    90898432      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0      3.99             21292                26          4.0              4.5
# 1      0.00            161065                26          4.0              3.5
# 2      0.00            188583              2822          3.5              4.5
# 3      0.00            262241               649          4.0              4.5
# 4      0.00            985920              5320          4.5              5.0
# 5      0.99              8253              5516          4.0              4.0
# 6      0.00            119487               879          4.0              4.5
# 7      0.00           1126879              3594          4.0              4.5
# 8      9.99              1117                 4          4.5              5.0
# 9      3.99              7885                40          4.0              4.0
# 10     4.99             76720              4017          4.5              4.5
# 11     7.99            105776               166          3.5              2.5
# 12     0.00            479440               203          3.5              4.0
# 13     0.00            119773              2336          3.5              4.5
# 14     4.99              6340               668          4.5              4.5
# 15     0.00             56194                87          4.0              3.5
# 16     0.00           2974676               212          3.5              3.5
# 17     0.00            223885              3726          4.0              4.5
# 18     0.00            402925               136          4.0              4.5
# 19     2.99             31456              4178          4.0              3.5
# 20     1.99              2929               966          4.5              4.5
# 21     2.99             11447               781          5.0              5.0
# 22     0.00            137951               131          4.0              4.5
# 23     5.99                 8                 0          4.5              0.0
# 24     3.99              3241               297          4.0              4.0
# 25     0.00              5795                12          3.5              4.0
# 26     0.00             42316               248          3.0              3.5
# 27     0.00            123215                25          3.5              5.0
# 28     4.99               782                 7          4.0              3.5
# 29     9.99              3449                23          4.0              4.5
# ...     ...               ...               ...          ...              ...
# 7167   0.00                 1                 1          1.0              1.0
# 7168   0.00                 3                 3          4.0              4.0
# 7169   2.99                 9                 3          3.0              3.5
# 7170   0.00                39                 4          5.0              5.0
# 7171   0.00                10                10          5.0              5.0
# 7172   3.99                55                29          4.5              4.5
# 7173   0.99                 0                 0          0.0              0.0
# 7174   0.00                14                 4          4.0              3.5
# 7175   0.00                41                19          4.5              4.5
# 7176   0.00                 0                 0          0.0              0.0
# 7177   0.00                11                 8          4.0              4.0
# 7178   0.99                 0                 0          0.0              0.0
# 7179   0.00               279                 5          3.5              3.0
# 7180   0.00                26                 3          5.0              5.0
# 7181   0.99                 0                 0          0.0              0.0
# 7182   0.00                 0                 0          0.0              0.0
# 7183   3.99               292               292          4.0              4.0
# 7184   0.00                 0                 0          0.0              0.0
# 7185   0.99                 0                 0          0.0              0.0
# 7186   0.00                 1                 1          2.0              2.0
# 7187   0.00                23                23          4.5              4.5
# 7188   0.00                18                18          4.0              4.0
# 7189   0.99                 0                 0          0.0              0.0
# 7190   2.99                97                97          3.0              3.0
# 7191   2.99                11                 0          4.0              0.0
# 7192   0.00               142                75          4.5              4.5
# 7193   0.00                30                30          4.5              4.5
# 7194   1.99                15                 0          4.5              0.0
# 7195   0.00                85                32          4.5              4.5
# 7196   0.00                 3                 3          5.0              5.0
#
#            ver cont_rating        prime_genre  sup_devices.num  \
# 0        6.3.5          4+              Games               38
# 1        8.2.2          4+       Productivity               37
# 2        5.0.0          4+            Weather               37
# 3       5.10.0         12+           Shopping               37
# 4        7.5.1          4+          Reference               37
# 5          1.8          4+              Games               47
# 6       6.12.0          4+            Finance               37
# 7        8.4.1         12+              Music               37
# 8        3.6.6          4+          Utilities               37
# 9        4.0.4          4+              Games               38
# 10      4.10.1          4+              Games               38
# 11      5.19.0          4+              Games               37
# 12          27         17+          Utilities               37
# 13       7.3.8          4+            Finance               37
# 14       4.0.3          4+              Games               38
# 15        21.1          4+             Travel               37
# 16          95          4+  Social Networking               37
# 17     11.15.0         12+             Travel               37
# 18      11.0.3         12+              Music               37
# 19       1.0.0          4+              Games               47
# 20         3.3          4+          Reference               43
# 21       5.2.6          4+              Games               40
# 22         6.9          4+             Sports               37
# 23       9.0.5          4+           Business               37
# 24       2.1.3          4+              Music               43
# 25       8.4.1          4+   Health & Fitness               37
# 26       2.0.6          9+              Games               38
# 27      10.5.4          4+       Productivity               37
# 28       1.9.8          4+              Music               43
# 29       3.4.1          4+            Weather               37
# ...        ...         ...                ...              ...
# 7167     1.0.1          4+              Games               38
# 7168     1.0.1          4+              Games               38
# 7169     1.0.1          4+      Entertainment               37
# 7170       1.3          9+  Social Networking               37
# 7171         1          4+              Games               40
# 7172       1.4          4+              Games               40
# 7173       1.1          4+          Utilities               37
# 7174     1.3.0          4+              Games               37
# 7175       1.3          4+              Games               37
# 7176     1.0.1          4+              Games               40
# 7177     1.1.0          4+              Games               37
# 7178       1.1          4+              Games               37
# 7179    0.6.41          4+  Social Networking               37
# 7180     1.0.5          9+          Utilities               37
# 7181         1          9+              Games               40
# 7182     1.0.3          4+      Photo & Video               37
# 7183  2.0.20.1          9+              Games               40
# 7184         1          9+              Games               40
# 7185         1          9+              Games               38
# 7186     1.0.1          4+              Games               38
# 7187         1          4+              Games               37
# 7188     1.0.0         12+              Games               38
# 7189     2.1.0          9+              Games               38
# 7190         1          4+              Games               37
# 7191     1.1.1         17+              Games               37
# 7192       1.3          4+              Games               38
# 7193       0.9          4+              Games               38
# 7194     1.0.2          9+          Utilities               37
# 7195    1.0.15         12+              Games               38
# 7196         1          4+              Games               40
#
#       ipadSc_urls.num  lang.num  vpp_lic
# 0                   5        10        1
# 1                   5        23        1
# 2                   5         3        1
# 3                   5         9        1
# 4                   5        45        1
# 5                   5         1        1
# 6                   0        19        1
# 7                   4         1        1
# 8                   5         1        1
# 9                   0        10        1
# 10                  4        11        1
# 11                  0         6        1
# 12                  4        33        1
# 13                  0         2        1
# 14                  5         2        1
# 15                  1        26        1
# 16                  1        29        1
# 17                  5        18        1
# 18                  3        16        1
# 19                  0         1        1
# 20                  0         2        1
# 21                  5         1        1
# 22                  2         6        1
# 23                  5         3        1
# 24                  2        10        1
# 25                  5        11        1
# 26                  0         1        1
# 27                  5        23        1
# 28                  1         1        1
# 29                  5         1        1
# ...               ...       ...      ...
# 7167                4         1        1
# 7168                5         1        1
# 7169                0        31        1
# 7170                1         1        1
# 7171                0         1        1
# 7172                5         1        1
# 7173                0         1        1
# 7174                5         1        1
# 7175                5        25        1
# 7176                4         1        1
# 7177                5         1        1
# 7178                5         1        1
# 7179                4         1        1
# 7180                4         1        1
# 7181                5         0        1
# 7182                0         1        1
# 7183                5         1        1
# 7184                5         0        1
# 7185                5         1        1
# 7186                5         1        1
# 7187                5         2        1
# 7188                4         1        1
# 7189                5         1        1
# 7190                5         3        1
# 7191                0         1        1
# 7192                5         1        1
# 7193                0         1        1
# 7194                1         1        1
# 7195                0         2        1
# 7196                0         2        1
#
# [7197 rows x 17 columns]

# %%
# List of all unique Prime_Genres(categories) in the data sets.
def categoriesUnique():
    categories= appstore["prime_genre"].unique()
    return [i for i in categories]
for i in categoriesUnique():
    print(i,end="| ")
#appstore.lx[(appstore["prime_genre"])]
#appstore.loc[appstore["prime_genre"]=="Games"]
# Out:
# Games| Productivity| Weather| Shopping| Reference| Finance| Music| Utilities| Travel| Social Networking| Sports| Business| Health & Fitness| Entertainment| Photo & Video| Navigation| Education| Lifestyle| Food & Drink| News| Book| Medical| Catalogs|

# %%
# Category with highest number of apps
def highestNumberOfApps():
    highestApps={}
    for i in appstore["prime_genre"]:
        if i not in highestApps: highestApps[i]=1
        else:highestApps[i]+=1
    # max(highestApps, key=highestApps.get)
    return max(highestApps, key=highestApps.get),highestApps[max(highestApps, key=highestApps.get)]
    #print(max(highestApps, key=highestApps.get),highestApps[max(highestApps, key=highestApps.get)])
highestNumberOfApps()

# Category with lowest number of apps
def lowestNumberOfApps():
    lowesttApps={}
    for i in appstore["prime_genre"]:
        if i not in lowesttApps: lowesttApps[i]=1
        else:lowesttApps[i]+=1
    return (min(lowesttApps,key=lowesttApps.get),lowesttApps[min(lowesttApps,key=lowesttApps.get)])

#lowestNumberOfApps()
print(highestNumberOfApps(),lowestNumberOfApps())
# Out:
# ('Games', 3862) ('Catalogs', 10)

# %%
# Category with highest user rating
def categoryHighestUserRating():
    categoryHighestUserRating={}
    #maxUserRating=max(appstore['user_rating'])
    maxUserRating=appstore.loc[(appstore['user_rating']==max(appstore['user_rating']))]
    for i in maxUserRating["prime_genre"]:
        if i not in categoryHighestUserRating:
            categoryHighestUserRating[i]=1
        else:
            categoryHighestUserRating[i]+=1
    highUserRating = max(categoryHighestUserRating,key=categoryHighestUserRating.get)
    highUserRatingNumber = categoryHighestUserRating[max(categoryHighestUserRating,key=categoryHighestUserRating.get)]
    print("'{}' with highest user rating of '{}'".format(highUserRating,highUserRatingNumber))
    #return appstore["prime_genre"].value_counts().idmax() + str(appstore['prime_genre'].value_counts().max())
    
    #print(maxUserRating["prime_genre"].unique())
    #print("User Highest Rating : ",maxUserRating)
categoryHighestUserRating()
# Out:
# 'Games' with highest user rating of '277'

# %%
# App with highest downloads
def appHighestDownloads():
    highestAppDownloads={}
    for i in range(len(appstore['track_name'])):
        highestAppDownloads[appstore['track_name'][i]]=appstore['rating_count_tot'][i]
    maxHighestDownloads=max(highestAppDownloads,key=highestAppDownloads.get)
    maxHighestDownloadsCount=highestAppDownloads[max(highestAppDownloads,key=highestAppDownloads.get)]
    print(maxHighestDownloads,maxHighestDownloadsCount)        
appHighestDownloads()
# Out:
# Facebook 2974676

# %%
# Category with highest average rating count
'''
def categoryHighestAvgRatingCount():
    #print(appstore["prime_genre"].value_counts())
    charc={}
    for rateCountTot in appstore['rating_count_tot']:
        rateC=[]
        s=0
        for category in appstore['prime_genre']:
            if category not in charc:
                charc[category]=rateCountTot
                print(charc[category])
            else:
                charc[category]+=rateCountTot               
                print(charc[category])
    print(charc)            
                
categoryHighestAvgRatingCount()
'''
def categoryHighestAvgRatingCount():
    pass
categoryHighestAvgRatingCount()
cate={}
rateGenre=appstore[{"rating_count_tot","prime_genre"}]
for k,v in rateGenre.items():
    cate[k]=v
cate
# Out:
# {'prime_genre': 0                   Games
#  1            Productivity
#  2                 Weather
#  3                Shopping
#  4               Reference
#  5                   Games
#  6                 Finance
#  7                   Music
#  8               Utilities
#  9                   Games
#  10                  Games
#  11                  Games
#  12              Utilities
#  13                Finance
#  14                  Games
#  15                 Travel
#  16      Social Networking
#  17                 Travel
#  18                  Music
#  19                  Games
#  20              Reference
#  21                  Games
#  22                 Sports
#  23               Business
#  24                  Music
#  25       Health & Fitness
#  26                  Games
#  27           Productivity
#  28                  Music
#  29                Weather
#                ...
#  7167                Games
#  7168                Games
#  7169        Entertainment
#  7170    Social Networking
#  7171                Games
#  7172                Games
#  7173            Utilities
#  7174                Games
#  7175                Games
#  7176                Games
#  7177                Games
#  7178                Games
#  7179    Social Networking
#  7180            Utilities
#  7181                Games
#  7182        Photo & Video
#  7183                Games
#  7184                Games
#  7185                Games
#  7186                Games
#  7187                Games
#  7188                Games
#  7189                Games
#  7190                Games
#  7191                Games
#  7192                Games
#  7193                Games
#  7194            Utilities
#  7195                Games
#  7196                Games
#  Name: prime_genre, Length: 7197, dtype: object,
#  'rating_count_tot': 0         21292
#  1        161065
#  2        188583
#  3        262241
#  4        985920
#  5          8253
#  6        119487
#  7       1126879
#  8          1117
#  9          7885
#  10        76720
#  11       105776
#  12       479440
#  13       119773
#  14         6340
#  15        56194
#  16      2974676
#  17       223885
#  18       402925
#  19        31456
#  20         2929
#  21        11447
#  22       137951
#  23            8
#  24         3241
#  25         5795
#  26        42316
#  27       123215
#  28          782
#  29         3449
#           ...
#  7167          1
#  7168          3
#  7169          9
#  7170         39
#  7171         10
#  7172         55
#  7173          0
#  7174         14
#  7175         41
#  7176          0
#  7177         11
#  7178          0
#  7179        279
#  7180         26
#  7181          0
#  7182          0
#  7183        292
#  7184          0
#  7185          0
#  7186          1
#  7187         23
#  7188         18
#  7189          0
#  7190         97
#  7191         11
#  7192        142
#  7193         30
#  7194         15
#  7195         85
#  7196          3
#  Name: rating_count_tot, Length: 7197, dtype: int64}

# %%
# Average user rating for free apps
def avgUserRatingFreeApps():
    avgFreePrice=appstore.loc[(appstore['price']==0)]
    sumRating=sum(avgFreePrice["user_rating"])
    avgFreeApps=sumRating/len(avgFreePrice["user_rating"])
    print("Average user rating for free apps : '{}'".format(avgFreeApps))
avgUserRatingFreeApps()
# Out:
# Average user rating for free apps : '3.3767258382642997'

# %%
# Average user rating for paid apps
def avgUserRatingPaidApps():
    avgPaidPrice = appstore.loc[(appstore['price']!=0)]
    sumRate = sum(avgPaidPrice["user_rating"])
    avgPaidApps=sumRate/len(avgPaidPrice['user_rating'])
    print("Average user rating for paid apps : '{}'".format(avgPaidApps))
avgUserRatingPaidApps()
# Out:
# Average user rating for paid apps : '3.720948742438714'

# %%
# Category with highest average user rating for paid apps
def highestAverageUserRatingPaidApps():
    pass
highestAverageUserRatingPaidApps()

# %%
# Most frequent Price Point > 0
def mostFrequentPricePointGreaterThanZero():
    greatThanZero=appstore.loc[(appstore["price"]>0)]
    mostFrequency=max(greatThanZero["price"].value_counts())
    print("Most frequent Price Point > 0 is : '{}'".format(mostFrequency))
mostFrequentPricePointGreaterThanZero()
# Out:
# Most frequent Price Point > 0 is : '728'

# %%
# Compare average user rating for paid vs free gaming apps
def compareAvgUserRatingPaidVsFreeGamingApps():
    #appstore.groupby(['prime_genre']).mean()
    freeGamingApps = appstore.loc[(appstore["price"]==0) & (appstore["prime_genre"]=="Games")]
    freeAvgRating = sum(freeGamingApps["user_rating"])/len(freeGamingApps["user_rating"])
    
    paidGamingApps = appstore.loc[(appstore["price"]>0) & (appstore["prime_genre"]=="Games")]
    paidAvgRating = sum(paidGamingApps["user_rating"])/len(paidGamingApps["user_rating"])
    print("Paid :{} \nFree : {}".format(paidAvgRating,freeAvgRating))
    #print(abs(paidAvgRating-freeAvgRating))
    
compareAvgUserRatingPaidVsFreeGamingApps()

#freeGamingApps = appstore.loc[(appstore["price"]==0) & (appstore["prime_genre"]=="Games")]
#freeGamingApps
# Out:
# Paid :3.9049844236760123
# Free : 3.5285777580859548

# %%
groupByPG_P=appstore.groupby(['prime_genre',"price"]).mean() # Unique Values with Avg
groupByPG_P[0:5]
# Out:
#                     Unnamed: 0            id    size_bytes  rating_count_tot  \
# prime_genre price
# Book        0.00   6219.348485  9.912704e+08  5.945220e+07       8498.333333
#             0.99   5586.000000  8.946131e+08  4.057984e+07          5.500000
#             1.99   5723.285714  9.202816e+08  1.045543e+08        224.714286
#             2.99   3942.444444  8.102705e+08  3.286924e+08         79.000000
#             3.99   5192.076923  9.505642e+08  2.555211e+08         39.384615
#
#                    rating_count_ver  user_rating  user_rating_ver  \
# prime_genre price
# Book        0.00         106.681818     1.598485         1.378788
#             0.99           0.000000     2.500000         0.000000
#             1.99          49.142857     4.142857         4.428571
#             2.99          18.666667     4.222222         3.888889
#             3.99          21.769231     4.000000         3.769231
#
#                    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# prime_genre price
# Book        0.00         37.651515         1.924242  1.924242      1.0
#             0.99         38.000000         0.750000  1.750000      1.0
#             1.99         37.571429         4.571429  9.000000      1.0
#             2.99         38.333333         4.777778  4.111111      1.0
#             3.99         37.538462         5.000000  1.307692      1.0

# %%
# Category with highest average user rating for paid apps
'''
def categoryHighestAvgUserRatingPaidApps():
    categoryPaidApps={}
    paidAppsData = appstore.loc[(appstore["price"]>0)]
    paidUnique=paidAppsData['prime_genre'].unique()
    highestAvg = paidAppsData.groupby(['prime_genre']).mean()

    for k,v in highestAvg['user_rating'].items():
        if k not in categoryPaidApps:
            categoryPaidApps[k]=v    
    #print(categoryPaidApps)
    print(max(categoryPaidApps,key=categoryPaidApps.get),categoryPaidApps[max(categoryPaidApps,key=categoryPaidApps.get)])
categoryHighestAvgUserRatingPaidApps()
'''
def categoryHighestAvgUserRatingPaidApps():
    #paidAppsData = appstore.loc[(appstore["price"]>0)]
    pass
categoryHighestAvgUserRatingPaidApps()

paidAppsData = appstore.loc[(appstore["price"]>0)]
paidUnique=paidAppsData['prime_genre'].unique()
paidAppsData
#highestAvg = paidAppsData.loc[(paidAppsData['prime_genre']==[i for i in paidUnique])]
#paidAppsData#[["prime_genre","user_rating"]]
# Out:
#       Unnamed: 0          id                                       track_name  \
# 0              1   281656475                                  PAC-MAN Premium
# 5              6   283619399                                 Shanghai Mahjong
# 8              9   284666222                      PCalc - The Best Calculator
# 9             10   284736660                                      Ms. PAC-MAN
# 10            11   284791396                        Solitaire by MobilityWare
# 11            12   284815117                                 SCRABBLE Premium
# 14            15   284862767                                         FreeCell
# 19            21   285005463                    Crash Bandicoot Nitro Kart 3D
# 20            22   285946052                                           iQuran
# 21            23   285994151                                      :) Sudoku +
# 23            25   286070473                        Mileage Log | Fahrtenbuch
# 24            27   286799607                      Cleartune - Chromatic Tuner
# 28            32   288120394                                         TouchOSC
# 29            33   288419283                                       RadarScope
# 31            35   289084315                            Period Tracker Deluxe
# 32            36   289446241                                Election 2016 Map
# 34            39   289894882                                      White Noise
# 36            41   290807369                                Line Rider iRide™
# 37            42   290986013                    Deliveries: a package tracker
# 38            43   291430598                                    Hurricane Pro
# 39            47   292421271                                     Fieldrunners
# 40            48   292628469                                       Juxtaposer
# 42            50   293118835                                         iStellar
# 44            52   293573778                                        Avertinoo
# 46            54   293760823             iFart - The Original Fart Sounds App
# 49            58   294536447                              First Words Animals
# 50            59   294631159                                       WeatherPro
# 51            60   294934058                                     HotSchedules
# 52            61   295430577  Star Walk - Find Stars And Planets in Sky Above
# 54            63   295759189                        Big Day - Event Countdown
# ...          ...         ...                                              ...
# 7117       10848  1176901281                         Web Browser Recorder Pro
# 7122       10871  1177806007                          Disaster Prediction App
# 7127       10884  1178433845                            新超级群英传OL-单机党必玩的三国群英手游
# 7131       10894  1178822943                      PetMojis' by The Dog Agency
# 7136       10907  1178973979                         PJ Masks: Super City Run
# 7137       10910  1179213211            VanDammemoji by Jean-Claude Van Damme
# 7139       10918  1179462965                                    Farming USA 2
# 7140       10919  1179475725                            Peppa Pig: Party Time
# 7143       10928  1179959829                        オービスガイド - 新型オービス&ネズミ捕り&検問
# 7146       10934  1180300366              Pitmoji - Pit Bull Emoji & Stickers
# 7152       10955  1180931796                                  椅子ドンVR~一ノ宮英介 編~
# 7154       10962  1181016912        Peanuts StoryGIF – Cute GIF & Story Maker
# 7155       10963  1181024195                         My Town : Beauty Contest
# 7156       10964  1181025437                             Demi Lovato Stickers
# 7159       10979  1181526812                                    EMOJIZI BOOBA
# 7160       10980  1181582218            Addon Creator Studio for Minecraft PE
# 7162       10982  1181616006                                     Island Delta
# 7164       10984  1181724803                                   ＣＲスーパー海物語ＩＮ沖縄４
# 7165       10989  1181855507                                         開園ピクセル牧場
# 7169       11002  1182568288      Talking Santa - Video santa claus calls you
# 7172       11016  1183548754                             Rescue the Enchanter
# 7173       11019  1183709176                               My Diary - 你的名字非官方
# 7178       11033  1185209084                                Saloons Unleashed
# 7181       11038  1185428381                                             剑倚手游
# 7183       11041  1185580782                                  Survivalcraft 2
# 7185       11043  1185777521                                   问仙奇遇-新玩法新套装嗨到爆
# 7189       11074  1187128255                       飞刀传奇-动作武侠热血江湖即时PK传奇（登录爆金装）
# 7190       11077  1187279979                     Add-Ons Studio for Minecraft
# 7191       11079  1187282363                       Plead the Fifth - The Game
# 7194       11087  1187779532            Bret Michaels Emojis + Lyric Keyboard
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0      100788224      USD   3.99             21292                26
# 5       10485713      USD   0.99              8253              5516
# 8       49250304      USD   9.99              1117                 4
# 9       70023168      USD   3.99              7885                40
# 10      49618944      USD   4.99             76720              4017
# 11     227547136      USD   7.99            105776               166
# 14      55153664      USD   4.99              6340               668
# 19      10735026      USD   2.99             31456              4178
# 20      70707916      USD   1.99              2929               966
# 21       6169600      USD   2.99             11447               781
# 23      71203840      USD   5.99                 8                 0
# 24      11423008      USD   3.99              3241               297
# 28       4263936      USD   4.99               782                 7
# 29     172772352      USD   9.99              3449                23
# 31      40216576      USD   1.99             13350               489
# 32       2386944      USD   0.99               137                 0
# 34      44129280      USD   0.99             33426               299
# 36       1646592      USD   1.99             21609                69
# 37      30016512      USD   4.99              4684                10
# 38      29518848      USD   2.99              2104                 0
# 39      66872320      USD   2.99             41633                 6
# 40      45229056      USD   2.99              3610                 7
# 42      44241920      USD   3.99                30                 0
# 44       8044544      USD   4.99                32                 0
# 46      60320768      USD   1.99             21825                10
# 49      32164864      USD   1.99              2576                 4
# 50      69079040      USD   1.99              1572                34
# 51      82037760      USD   2.99              3292                 2
# 52     150195200      USD   4.99              8932                55
# 54      13156352      USD   0.99               812                14
# ...          ...      ...    ...               ...               ...
# 7117     1734656      USD   1.99                14                 3
# 7122    26094592      USD   2.99                32                 9
# 7127   246023168      USD   0.99                 1                 1
# 7131    84905984      USD   0.99                79                 2
# 7136   343991296      USD   2.99                12                12
# 7137    17164288      USD   0.99                18                 0
# 7139   299749376      USD   2.99               269                35
# 7140   251977728      USD   0.99                 9                 0
# 7143    65525760      USD   1.99                 0                 0
# 7146    32785408      USD   2.99                29                29
# 7152   161346560      USD   3.99                 0                 0
# 7154    37198848      USD   0.99                 5                 4
# 7155   203589632      USD   2.99                31                31
# 7156    88388608      USD   0.99                12                 8
# 7159    52536320      USD   1.99                 1                 1
# 7160    61915136      USD   1.99               214               137
# 7162   628180992      USD   2.99                26                 0
# 7164  3503480832      USD   9.99                 0                 0
# 7165   192621568      USD   4.99                 0                 0
# 7169    32685056      USD   2.99                 9                 3
# 7172   242505728      USD   3.99                55                29
# 7173    18164736      USD   0.99                 0                 0
# 7178   327731200      USD   0.99                 0                 0
# 7181   178160640      USD   0.99                 0                 0
# 7183    57349120      USD   3.99               292               292
# 7185   208026624      USD   0.99                 0                 0
# 7189   537462784      USD   0.99                 0                 0
# 7190    22999040      USD   2.99                97                97
# 7191    27853824      USD   2.99                11                 0
# 7194   111322112      USD   1.99                15                 0
#
#       user_rating  user_rating_ver         ver cont_rating        prime_genre  \
# 0             4.0              4.5       6.3.5          4+              Games
# 5             4.0              4.0         1.8          4+              Games
# 8             4.5              5.0       3.6.6          4+          Utilities
# 9             4.0              4.0       4.0.4          4+              Games
# 10            4.5              4.5      4.10.1          4+              Games
# 11            3.5              2.5      5.19.0          4+              Games
# 14            4.5              4.5       4.0.3          4+              Games
# 19            4.0              3.5       1.0.0          4+              Games
# 20            4.5              4.5         3.3          4+          Reference
# 21            5.0              5.0       5.2.6          4+              Games
# 23            4.5              0.0       9.0.5          4+           Business
# 24            4.0              4.0       2.1.3          4+              Music
# 28            4.0              3.5       1.9.8          4+              Music
# 29            4.0              4.5       3.4.1          4+            Weather
# 31            4.5              5.0         9.6         12+   Health & Fitness
# 32            3.0              0.0           5          4+      Entertainment
# 34            4.0              5.0         7.2          4+   Health & Fitness
# 36            3.5              2.5         2.4          9+      Entertainment
# 37            4.0              4.0       8.0.3          4+          Utilities
# 38            4.5              0.0         5.2         17+            Weather
# 39            4.0              3.0  1.7.177604          9+              Games
# 40            4.5              5.0       3.8.2          4+      Photo & Video
# 42            3.5              0.0       2.9.0          4+         Navigation
# 44            3.0              0.0       3.9.2          4+         Navigation
# 46            3.0              4.0       4.0.8          9+      Entertainment
# 49            4.0              5.0           7          4+              Games
# 50            4.0              4.5       4.8.2          4+            Weather
# 51            3.0              5.0      4.56.1          4+           Business
# 52            4.5              5.0       7.2.3          4+          Education
# 54            3.0              4.0       8.2.0          4+          Lifestyle
# ...           ...              ...         ...         ...                ...
# 7117          2.0              4.5         1.2         17+          Utilities
# 7122          4.5              4.5         1.7         12+          Lifestyle
# 7127          4.0              4.0         1.6          9+              Games
# 7131          2.0              1.0       1.1.1          4+      Entertainment
# 7136          2.5              2.5           1          4+      Entertainment
# 7137          4.5              0.0         1.3         12+      Entertainment
# 7139          4.5              4.5        1.33          4+              Games
# 7140          2.0              0.0       1.1.6          4+          Education
# 7143          0.0              0.0       1.1.1          4+         Navigation
# 7146          3.0              3.0           1         12+      Entertainment
# 7152          0.0              0.0       1.0.3         12+      Entertainment
# 7154          2.5              2.0         1.2          4+      Entertainment
# 7155          4.5              4.5           1          4+              Games
# 7156          3.5              3.5         1.1         12+  Social Networking
# 7159          4.0              4.0       1.0.1         17+          Utilities
# 7160          4.0              4.5         1.2         12+      Entertainment
# 7162          4.5              0.0       1.2.4          9+              Games
# 7164          0.0              0.0       1.0.2         12+              Games
# 7165          0.0              0.0       1.0.6          4+              Games
# 7169          3.0              3.5       1.0.1          4+      Entertainment
# 7172          4.5              4.5         1.4          4+              Games
# 7173          0.0              0.0         1.1          4+          Utilities
# 7178          0.0              0.0         1.1          4+              Games
# 7181          0.0              0.0           1          9+              Games
# 7183          4.0              4.0    2.0.20.1          9+              Games
# 7185          0.0              0.0           1          9+              Games
# 7189          0.0              0.0       2.1.0          9+              Games
# 7190          3.0              3.0           1          4+              Games
# 7191          4.0              0.0       1.1.1         17+              Games
# 7194          4.5              0.0       1.0.2          9+          Utilities
#
#       sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0                  38                5        10        1
# 5                  47                5         1        1
# 8                  37                5         1        1
# 9                  38                0        10        1
# 10                 38                4        11        1
# 11                 37                0         6        1
# 14                 38                5         2        1
# 19                 47                0         1        1
# 20                 43                0         2        1
# 21                 40                5         1        1
# 23                 37                5         3        1
# 24                 43                2        10        1
# 28                 43                1         1        1
# 29                 37                5         1        1
# 31                 38                0        15        1
# 32                 37                1         1        1
# 34                 37                5         3        1
# 36                 40                0         1        1
# 37                 37                4         9        1
# 38                 37                0         1        1
# 39                 37                0         1        1
# 40                 37                5         1        1
# 42                 37                0         2        0
# 44                 38                5         7        1
# 46                 37                5         1        1
# 49                 38                5         1        1
# 50                 37                0        13        1
# 51                 37                2         2        1
# 52                 37                0        12        1
# 54                 38                0         7        1
# ...               ...              ...       ...      ...
# 7117               37                0         3        1
# 7122               37                0         1        1
# 7127               37                5         1        1
# 7131               37                0         1        1
# 7136               37                5         1        1
# 7137               37                0         1        1
# 7139               37                5         1        1
# 7140               40                5         1        1
# 7143               37                5         1        1
# 7146               37                4         1        1
# 7152               37                5         1        1
# 7154               37                3         9        1
# 7155               37                5         1        1
# 7156               37                0         1        1
# 7159               37                0         1        1
# 7160               37                4         1        1
# 7162               37                5         1        1
# 7164               40                0         1        0
# 7165               38                5         1        1
# 7169               37                0        31        1
# 7172               40                5         1        1
# 7173               37                0         1        1
# 7178               37                5         1        1
# 7181               40                5         0        1
# 7183               40                5         1        1
# 7185               38                5         1        1
# 7189               38                5         1        1
# 7190               37                5         3        1
# 7191               37                0         1        1
# 7194               37                1         1        1
#
# [3141 rows x 17 columns]
